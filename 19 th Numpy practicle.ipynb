# %% [markdown]
# # numpy practicle

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
from PIL import Image

# %%
jk_image=Image.open(r'C:\Users\admin\OneDrive\Desktop\jk.jpeg')

# %%
jk_image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=225x225>

# %%
type(jk_image)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
jk_arr=np.asarray(jk_image)
jk_arr
# Out:
# array([[[242, 251, 250],
#         [241, 250, 249],
#         [240, 249, 248],
#         ...,
#         [251, 255, 254],
#         [254, 255, 255],
#         [252, 255, 255]],
#
#        [[233, 242, 241],
#         [234, 243, 242],
#         [234, 243, 242],
#         ...,
#         [248, 252, 251],
#         [250, 254, 253],
#         [252, 255, 255]],
#
#        [[224, 233, 232],
#         [226, 235, 234],
#         [228, 236, 238],
#         ...,
#         [243, 252, 249],
#         [245, 251, 249],
#         [247, 255, 255]],
#
#        ...,
#
#        [[181, 215, 216],
#         [180, 214, 215],
#         [177, 213, 213],
#         ...,
#         [ 93, 142, 149],
#         [ 96, 143, 151],
#         [ 93, 144, 147]],
#
#        [[175, 211, 211],
#         [173, 209, 209],
#         [170, 206, 206],
#         ...,
#         [142, 189, 197],
#         [138, 185, 193],
#         [131, 182, 186]],
#
#        [[166, 207, 209],
#         [161, 202, 204],
#         [153, 197, 198],
# ...

# %%
plt.imshow(jk_image)

# %%
jk_arr.shape
# Out:
# (225, 225, 3)
