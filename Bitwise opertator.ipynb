# %% [markdown]
# # Bitwise operator

# %%
'''bitwise opertator are
1.complement(~)
2.AND(&)
3.OR(|)
4.XOR(^)
5.right shift(>>)
6.Left shift(<<)
'''

# %% [markdown]
# # 1.complement(~)

# %%
~45  #{45+1}
# Out:
# -46

# %%
~50
# Out:
# -51

# %%
~-50
# Out:
# 49

# %% [markdown]
# # 2.AND(&)

# %%
25&50
# Out:
# 16

# %%
0b110010
# Out:
# 50

# %%
12&13
# Out:
# 12

# %%
0b1101
# Out:
# 13

# %% [markdown]
# # 3. OR(|)

# %%
25|50
# Out:
# 59

# %%
bin(50)
# Out:
# '0b110010'

# %%
bin(25)
# Out:
# '0b11001'

# %%
0b110010|0b11001
# Out:
# 59

# %%
12|42
# Out:
# 46

# %%
1|0
# Out:
# 1

# %%
0|0
# Out:
# 0

# %% [markdown]
# # 4.XOR(^)

# %%
25^24
# Out:
# 1

# %%
bin(1)
# Out:
# '0b1'

# %%
32^500
# Out:
# 468

# %% [markdown]
# # 5.right shift(>>)

# %%
25>>24
# Out:
# 0

# %%
12>>2    #we can remove first 2 "zeros" in right shift operator
# Out:
# 3

# %%
2005>>10
# Out:
# 1

# %% [markdown]
# # 6.Left shift(<<)

# %%
12<<2 # we must remove "2" zeros from binary code
# Out:
# 48

# %%
13<<1
# Out:
# 26

# %%
1<<0
# Out:
# 1

# %%
2<<35
# Out:
# 68719476736
