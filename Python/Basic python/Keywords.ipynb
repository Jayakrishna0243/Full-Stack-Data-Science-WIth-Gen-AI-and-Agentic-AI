# %% [markdown]
# # keywords

# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %% [markdown]
# # Numbers

# %%
3
# Out:
# 3

# %%
3+2
# Out:
# 5

# %%
3-5
# Out:
# -2

# %%
3*2*5
# Out:
# 30

# %%
3/3
# Out:
# 1.0

# %%
2/32
# Out:
# 0.0625

# %% [markdown]
# # Variables

# %%
a=20
b=30
# without print only one value will print
a-b
a+b
# Out:
# 50

# %% [markdown]
# # Variable with print statemet

# %%
a=20
b=30
# using print statements 
print(a-b)
print(a+b)
# Out:
# -10
# 50

# %%
#variable value
first_name='podilapu'
last_name='jayakrishna'
country='india'
city='rajam'
is_married=False
age=20
skills=['python','css','html','java']
person_info={
    'firstname':'Mr',
    'lastname':'jayakrishna',
    'city':'rajam',
    'state':'andhrapradesh',
}
#print variable
print('First name:', first_name)
print('First name length:', len(first_name))
print('Last name: ', last_name)
print('Last name length: ', len(last_name))
print('Country: ', country)
print('City: ', city)
print('Age: ', age)
print('Married: ', is_married)
print('Skills: ', skills)
print('Person information: ', person_info) 
#multiple line variable value in single
first_name, last_name, country, age, is_married = 'podilapu', 'jayakrishna', 'Helsink', 250, True
print(first_name, last_name, country, age, is_married)
print('First name:', first_name)
print('Last name: ', last_name)
print('Country: ', country)
print('Age: ', age)
print('Married: ', is_married)
# Out:
# First name: podilapu
# First name length: 8
# Last name:  jayakrishna
# Last name length:  11
# Country:  india
# City:  rajam
# Age:  20
# Married:  False
# Skills:  ['python', 'css', 'html', 'java']
# Person information:  {'firstname': 'Mr', 'lastname': 'jayakrishna', 'city': 'rajam', 'state': 'andhrapradesh'}
# podilapu jayakrishna Helsink 250 True
# First name: podilapu
# Last name:  jayakrishna
# Country:  Helsink
# Age:  250
# Married:  True
