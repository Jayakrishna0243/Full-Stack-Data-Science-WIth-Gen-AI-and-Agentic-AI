# %% [markdown]
# #Data types

# %%
'''datatypes are
int
Float
complex
boolean'''

# %% [markdown]
# # int datatype

# %%
a=20
print(a)
print(type(a))
# Out:
# 20
# <class 'int'>

# %% [markdown]
# # float datatype

# %%
a=20.000
print(type(a))
print(a)
# Out:
# <class 'float'>
# 20.0

# %% [markdown]
# # int,flaot datatypes

# %%
a=20
b=23.00
print(type(a))
print(type(b))
print(a+b)
# Out:
# <class 'int'>
# <class 'float'>
# 43.0

# %% [markdown]
# # complex datatype

# %%
a=10+20j
b=300+400j
print(type(a))
print(type(b))
print(a+b)
# Out:
# <class 'complex'>
# <class 'complex'>
# (310+420j)

# %% [markdown]
# # boolean datatype

# %%
a=True
print(a)
print(type(a))
# Out:
# True
# <class 'bool'>

# %%
a=False
print(type(a))
# Out:
# <class 'bool'>
