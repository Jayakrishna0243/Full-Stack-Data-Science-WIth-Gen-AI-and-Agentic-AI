# %% [markdown]
# # type casting

# %%
'''typecasting one datatype to other datataype
int<<float
float<<int
int<<bool
bool<<int'''

# %% [markdown]
# # int type casting

# %%
int(3.5)
# Out:
# 3

# %%
int(35)
# Out:
# 35.0

# %%
int(True)
# Out:
# 1

# %%
int('200')
# Out:
# 200

# %%
int('jaya')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 int('jaya')
#
# ValueError: invalid literal for int() with base 10: 'jaya'

# %%
int(False)
# Out:
# 0

# %%
int(19+10j)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 int(19+10j)
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'complex'

# %% [markdown]
# # Float typecating

# %%
float(3)
# Out:
# 3.0

# %%
float(True)
# Out:
# 1.0

# %%
float(False)
# Out:
# 0.0

# %%
float(3,3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 float(3,3)
#
# TypeError: float expected at most 1 argument, got 2

# %%
float('23.55')
# Out:
# 23.55

# %%
float(10+20j)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 float(10+20j)
#
# TypeError: float() argument must be a string or a real number, not 'complex'

# %% [markdown]
# # complex typecasting

# %%
complex(20+30j)
# Out:
# (20+30j)

# %%
complex(10,20,30)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 complex(10,20,30)
#
# TypeError: complex() takes at most 2 arguments (3 given)

# %%
complex(2+10.5j)
# Out:
# (2+10.5j)

# %%
complex(2+22j,30+40j)
# Out:
# (-38+52j)

# %%
complex('string')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 complex('string')
#
# ValueError: complex() arg is a malformed string

# %%
complex('20')
# Out:
# (20+0j)

# %%
complex('20,30')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 complex('20,30')
#
# ValueError: complex() arg is a malformed string

# %%
complex('30')
# Out:
# (30+0j)

# %%
complex(True)
# Out:
# (1+0j)

# %%
complex(0)
# Out:
# 0j

# %%
complex(False)
# Out:
# 0j

# %% [markdown]
# # Boolean typecasting

# %%
bool(True)
# Out:
# True

# %%
bool(1)
# Out:
# True

# %%
bool(250.00)
# Out:
# True

# %%
bool(0.1)
# Out:
# True

# %%
bool(10+20j)
# Out:
# True

# %%
bool('233')
# Out:
# True

# %% [markdown]
# # string typecasting

# %%
str(20)
# Out:
# '20'

# %%
str(2.3)
# Out:
# '2.3'

# %%
str(2.355)
# Out:
# '2.355'

# %%
str(True)
# Out:
# 'True'
